# %%
import pandas as pd 

df = pd.read_csv("../../data/election.txt", sep="\t")

df.head()
# Out:
#      state   county  trump16_pct  clinton16_pct  otherpres16_pct  \
# 0  Alabama  Autauga     0.727666       0.237697         0.034637
# 1  Alabama  Baldwin     0.765457       0.193856         0.040687
# 2  Alabama  Barbour     0.520967       0.465278         0.013755
# 3  Alabama     Bibb     0.764032       0.212496         0.023472
# 4  Alabama   Blount     0.893348       0.084258         0.022393
#
#    romney12_pct  obama12_pct  otherpres12_pct senaterace16 houserace16  ...  \
# 0      0.726183     0.265878         0.007939         Race        Race  ...
# 1      0.773583     0.215894         0.010523         Race        Race  ...
# 2      0.482231     0.513685         0.004084         Race        Race  ...
# 3      0.728266     0.261520         0.010214         Race        Race  ...
# 4      0.864659     0.123719         0.011622         Race        Race  ...
#
#   hispanic_pct  foreignborn_pct  female_pct  age29andunder_pct  \
# 0     2.572254         1.838362   51.176225          40.037058
# 1     4.366698         3.269510   51.194928          35.474412
# 2     4.309762         2.859397   46.498084          37.664387
# 3     2.223994         1.351232   46.464646          37.329435
# 4     8.727298         4.271801   50.485235          37.240053
#
#    age65andolder_pct  median_hh_inc  clf_unemploy_pct  lesshs_pct  \
# 0          13.978456          53099          5.591657   12.417046
# 1          18.714851          51365          6.286843    9.972418
# 2          16.528895          33956         12.824738   26.235928
# 3          14.885699          39776          7.146827   19.301587
# 4          17.192916          46212          5.953833   19.968585
#
#    lesscollege_pct  rural_pct
# 0        75.407229  42.002162
# 1        70.452889  42.279099
# 2        87.132213  67.789635
# 3        88.000000  68.352607
# 4        86.950243  89.951502
#
# [5 rows x 29 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(df, x="voterturnout12_pct", y="voterturnout16_pct")
plt.show()

# %%
# The excercise mentions "investigate counties where voter turnout > 100%"
# Im not sure why this would be

greater_than_100 = df[(df["voterturnout12_pct"] > 1) | (df["voterturnout16_pct"] > 1)]
greater_than_100.head()

# It asks me why, but im not sure, voter fraud?
# Out:
#              state    county  trump16_pct  clinton16_pct  otherpres16_pct  \
# 271       Colorado  San Juan     0.424901       0.523715         0.051383
# 1776    New Mexico   Harding     0.590133       0.296015         0.113852
# 2361  South Dakota    Hanson     0.746261       0.211366         0.042373
# 2642         Texas    Loving     0.892308       0.061538         0.046154
# 2647         Texas  McMullen     0.909820       0.080160         0.010020
#
#       romney12_pct  obama12_pct  otherpres12_pct senaterace16 houserace16  \
# 271       0.418972     0.525692         0.055336         Race        Race
# 1776      0.544093     0.432612         0.023295      No Race        Race
# 2361      0.673427     0.314570         0.012003         Race        Race
# 2642      0.843750     0.140625         0.015625      No Race        Race
# 2647      0.856859     0.133201         0.009940      No Race        Race
#
#       ... hispanic_pct  foreignborn_pct  female_pct  age29andunder_pct  \
# 271   ...    23.550725         0.543478   47.282609          27.355072
# 1776  ...    41.946903         0.176991   48.672566          21.415929
# 2361  ...     0.589971         0.058997   49.144543          43.333333
# 2642  ...    15.789474        11.842105   47.368421          11.842105
# 2647  ...    48.137109         6.706408   45.603577          44.560358
#
#       age65andolder_pct  median_hh_inc  clf_unemploy_pct  lesshs_pct  \
# 271           17.028986          41250         10.282776    4.595186
# 1776          28.849558          32404          5.963303   11.013216
# 2361          13.775811          60089          0.347423    7.826932
# 2642          25.000000          56875          0.000000   25.373134
# 2647          28.017884          57589         15.151515   18.565401
#
#       lesscollege_pct  rural_pct
# 271         71.553611      100.0
# 1776        74.229075      100.0
# 2361        78.609626      100.0
# 2642        97.014925      100.0
# 2647        83.755274      100.0
#
# [5 rows x 29 columns]

# %%
#
all_below_100 = df[(df["voterturnout12_pct"] < 1) & (df["voterturnout16_pct"] < 1)]
all_below_100.head()

sns.scatterplot(all_below_100, x="voterturnout12_pct", y="voterturnout16_pct")
plt.show()

# %%
# it looks like a linear, positive and strong correlation
print(df["voterturnout12_pct"].corr(df["voterturnout16_pct"]))
# 0.924 so very strong
# Out:
# 0.9243095587512101
